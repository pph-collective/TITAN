# %%
import ABM_core as tc

# %%
TMP = tc.HIVModel(100, 12, {}, 1)
TMP.run()
# Out:
# 	FIRST RANDOM CALL 13
#
#  === Begin Initialization Protocol ===
#
# 	Dictionary Read
# 	Creating population Class
# 1
# W: 100, B: 0
# 	Building class sets
# 	Organizing subsets and heirarchy
# 	Creating agents
# 25%
# 50%
# 75%
# 	_____________ TotalAgents Subsets _____________
# 	ID		Members	%
# 	HIV		3	0.03
# 	IDU		2	0.02
# 	HAART		2	0.67
# 	HM		46	0.46
# 	HF		54	0.54
# 	______________ END ______________
#
# 	Creating lists
# 	Reseting death count
#
#  === Initialization Protocol Finished ===
#
# RANDOM CALL 0
#
# 																			.: BURNTIME 0
# Added 100/100 agents
# Number of relationships: 105
# Number tested: 3	1.00
#
# 																			.: BURNTIME 1
# Number of relationships: 112
# Number tested: 3	1.00
# 	_____________ TotalAgents Subsets _____________
# 	ID		Members	%
# 	HIV		3	0.03
# 	IDU		2	0.02
# 	HAART		2	0.67
# 	HM		46	0.46
# 	HF		54	0.54
# 	______________ END ______________
# BurnCumlInc	%d 0
# RANDOM CALL 6
#
#  === Begin Simulation Run ===
#
# ...

# %%
TMP2 = tc.HIVModel(100, 12, {}, 1)
TMP2.run()
# Out:
# 	FIRST RANDOM CALL 13
#
#  === Begin Initialization Protocol ===
#
# 	Dictionary Read
# 	Creating population Class
# 1
# W: 100, B: 0
# 	Building class sets
# 	Organizing subsets and heirarchy
# 	Creating agents
# 25%
# 50%
# 75%
# 	_____________ TotalAgents Subsets _____________
# 	ID		Members	%
# 	HIV		3	0.03
# 	IDU		2	0.02
# 	HAART		2	0.67
# 	HM		46	0.46
# 	HF		54	0.54
# 	______________ END ______________
#
# 	Creating lists
# 	Reseting death count
#
#  === Initialization Protocol Finished ===
#
# RANDOM CALL 0
#
# 																			.: BURNTIME 0
# Added 100/100 agents
# Number of relationships: 105
# Number tested: 3	1.00
#
# 																			.: BURNTIME 1
# Number of relationships: 112
# Number tested: 3	1.00
# 	_____________ TotalAgents Subsets _____________
# 	ID		Members	%
# 	HIV		3	0.03
# 	IDU		2	0.02
# 	HAART		2	0.67
# 	HM		46	0.46
# 	HF		54	0.54
# 	______________ END ______________
# BurnCumlInc	%d 0
# RANDOM CALL 6
#
#  === Begin Simulation Run ===
#
# ...
